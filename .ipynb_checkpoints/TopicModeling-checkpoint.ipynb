# %% [markdown]
# # Topic modeling with Scikit Testing
#
# - Brian Kalinowski 11/3/2019

# %%
import pandas as pd
import numpy as np
from collections import *
from typing import *
import string
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation, TruncatedSVD
import pyLDAvis.sklearn

# %%
fake_news_content = pd.read_csv('/Users/briankalinowski/Desktop/Data/fake_news_nlp_content.csv')
fake_news_content.head()
# Out:
#                                                title  \
# 0  Muslims BUSTED They Stole Millions In Govt Ben...
# 1  Re Why Did Attorney General Loretta Lynch Plea...
# 2  BREAKING Weiner Cooperating With FBI On Hillar...
# 3  PIN DROP SPEECH BY FATHER OF DAUGHTER Kidnappe...
# 4  FANTASTIC! TRUMPS 7 POINT PLAN To Reform Healt...
#
#                                                 text  type  \
# 0  Print They should pay all the back all the mon...  bias
# 1  Why Did Attorney General Loretta Lynch Plead T...  bias
# 2  Red State Fox News Sunday reported this mornin...  bias
# 3  Email Kayla Mueller was a prisoner and torture...  bias
# 4  Email HEALTHCARE REFORM TO MAKE AMERICA GREAT ...  bias
#
#                        tokenized_headline  \
# 0                                 muslims
# 1                           loretta lynch
# 2  weiner fbi hillary email investigation
# 3                         donald j. trump
# 4                                 notokes
#
#                                    tokenized_content
# 0                                            somalis
# 1  loretta lynch barracuda brigade iran loretta l...
# 2  red state fox news anthony weiner fbi hillary ...
# 3       kayla mueller isis carl mueller donald trump
# 4  house senate obamacare obamacare democrats oba...

# %%
vectorizer = CountVectorizer(min_df=10, stop_words=['notokes'])
content_vectorized = vectorizer.fit_transform(fake_news_content.tokenized_content)

# %%
lda = LatentDirichletAllocation(n_components=10, max_iter=10, learning_method='online', verbose=True)
fake_news_topics = lda.fit_transform(content_vectorized)
# Out:
# iteration: 1 of max_iter: 10
# iteration: 2 of max_iter: 10
# iteration: 3 of max_iter: 10
# iteration: 4 of max_iter: 10
# iteration: 5 of max_iter: 10
# iteration: 6 of max_iter: 10
# iteration: 7 of max_iter: 10
# iteration: 8 of max_iter: 10
# iteration: 9 of max_iter: 10
# iteration: 10 of max_iter: 10

# %%
pyLDAvis.enable_notebook()
dash = pyLDAvis.sklearn.prepare(lda, content_vectorized, vectorizer, sort_topics=True, mds='tsne')
dash
# Out:
# /anaconda/envs/FakeNewsChallenge/lib/python3.7/site-packages/pyLDAvis/_prepare.py:257: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   return pd.concat([default_term_info] + list(topic_dfs))
# PreparedData(topic_coordinates=                x           y  topics  cluster       Freq
# topic
# 9       23.635321 -103.440170       1        1  16.099108
# 0        7.823198  112.654900       2        1  15.897678
# 3      -72.128998  -70.704834       3        1  11.926876
# 7       96.916115   64.497276       4        1   9.903980
# 6       26.899826   35.832146       5        1   9.895031
# 1      -47.159771   27.302677       6        1   8.960556
# 5       -2.688618  -32.531433       7        1   8.227978
# 4     -120.559990    3.945732       8        1   6.772732
# 2      -79.728065   97.133057       9        1   6.604542
# 8       83.610519  -29.568253      10        1   5.711518, topic_info=     Category          Freq      Term         Total  loglift  logprob
# 792   Default  19016.000000   clinton  19016.000000  30.0000  30.0000
# 4050  Default  18456.000000     trump  18456.000000  29.0000  29.0000
# 1777  Default  13783.000000   hillary  13783.000000  28.0000  28.0000
# 1382  Default   5656.000000       fbi   5656.000000  27.0000  27.0000
# 3479  Default   6841.000000    russia   6841.000000  26.0000  26.0000
# ...       ...           ...       ...           ...      ...      ...
# 4249  Topic10    313.046378       war   2327.657411   0.8564  -4.5659
# 2752  Topic10    267.244942  national   1936.457176   0.8822  -4.7241
# 2086  Topic10    284.342549      john   2703.361839   0.6106  -4.6621
# 3986  Topic10    243.254169     times   1817.219012   0.8517  -4.8182
# 3799  Topic10    221.742877     state   3224.179973   0.1858  -4.9108
#
# [618 rows x 6 columns], token_table=      Topic      Freq        Term
# term
# 17        5  0.054122      abedin
# 17        7  0.944888      abedin
# 18        7  0.990460     abedins
# 21        5  0.986476   abramovic
# 27        8  0.998194      access
# ...     ...       ...         ...
# 4409      6  0.589109     youtube
# 4418      4  0.994772     zealand
# 4422      4  0.995473        zika
# 4428      9  0.985956    zionists
# 4431      3  0.994343  zuckerberg
#
# [1194 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[10, 1, 4, 8, 7, 2, 6, 5, 3, 9])

# %%
news_topics = pd.Series([fake_news_topics[n].argmax() for n in range(fake_news_topics.shape[0])])
fake_news_content['topic_id'] = news_topics
fake_news_content.head()
# Out:
#                                                title  \
# 0  Muslims BUSTED They Stole Millions In Govt Ben...
# 1  Re Why Did Attorney General Loretta Lynch Plea...
# 2  BREAKING Weiner Cooperating With FBI On Hillar...
# 3  PIN DROP SPEECH BY FATHER OF DAUGHTER Kidnappe...
# 4  FANTASTIC! TRUMPS 7 POINT PLAN To Reform Healt...
#
#                                                 text  type  \
# 0  Print They should pay all the back all the mon...  bias
# 1  Why Did Attorney General Loretta Lynch Plead T...  bias
# 2  Red State Fox News Sunday reported this mornin...  bias
# 3  Email Kayla Mueller was a prisoner and torture...  bias
# 4  Email HEALTHCARE REFORM TO MAKE AMERICA GREAT ...  bias
#
#                        tokenized_headline  \
# 0                                 muslims
# 1                           loretta lynch
# 2  weiner fbi hillary email investigation
# 3                         donald j. trump
# 4                                 notokes
#
#                                    tokenized_content  topic_id
# 0                                            somalis         0
# 1  loretta lynch barracuda brigade iran loretta l...         6
# 2  red state fox news anthony weiner fbi hillary ...         5
# 3       kayla mueller isis carl mueller donald trump         9
# 4  house senate obamacare obamacare democrats oba...         8

# %%
# news_clusters = pd.DataFrame(fake_news_content.groupby(['topic_id', 'type']).type.count())
# pd.options.display.max_rows = 100
# news_clusters

# %%
topic_clusters = pd.DataFrame(fake_news_topics)
# Out:
#               0         1         2         3         4         5         6  \
# 0      0.100000  0.100000  0.100000  0.100000  0.100000  0.100000  0.100000
# 1      0.120423  0.002942  0.002941  0.002941  0.002942  0.382614  0.476371
# 2      0.004546  0.004547  0.004546  0.004545  0.100814  0.862817  0.004546
# 3      0.020004  0.020000  0.214723  0.020000  0.020000  0.020000  0.020001
# 4      0.006667  0.006667  0.006667  0.006667  0.006667  0.006667  0.006667
# ...         ...       ...       ...       ...       ...       ...       ...
# 12352  0.100000  0.100000  0.100000  0.100000  0.100000  0.100000  0.100000
# 12353  0.100000  0.100000  0.100000  0.100000  0.100000  0.100000  0.100000
# 12354  0.100000  0.100000  0.100000  0.100000  0.100000  0.100000  0.100000
# 12355  0.100000  0.100000  0.100000  0.100000  0.100000  0.100000  0.100000
# 12356  0.100000  0.100000  0.100000  0.100000  0.100000  0.100000  0.100000
#
#               7         8         9
# 0      0.100000  0.100000  0.100000
# 1      0.002942  0.002941  0.002942
# 2      0.004546  0.004546  0.004546
# 3      0.020004  0.020000  0.625268
# 4      0.073861  0.585083  0.294389
# ...         ...       ...       ...
# 12352  0.100000  0.100000  0.100000
# 12353  0.100000  0.100000  0.100000
# 12354  0.100000  0.100000  0.100000
# 12355  0.100000  0.100000  0.100000
# 12356  0.100000  0.100000  0.100000
#
# [12357 rows x 10 columns]

# %%
from sklearn.manifold import TSNE
from sklearn.preprocessing import LabelEncoder

tsne_model = TSNE(n_components=2, init='pca')
tsne_clusters = tsne_model.fit_transform(topic_clusters)

# %%
df = pd.DataFrame(tsne_clusters, columns=['X', 'Y'])
df['type'] = LabelEncoder().fit_transform(fake_news_content.type)
df['topic_id'] = fake_news_content['topic_id']
df.head()
# Out:
#            X          Y  type  topic_id
# 0 -13.988557  68.079475     0         0
# 1  34.646370  52.365635     0         6
# 2  77.355957 -28.323425     0         5
# 3  51.278103  38.419476     0         9
# 4   2.357099  14.072436     0         8

# %%
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(16,7))
sns.scatterplot(x=df.X, y=df.Y, hue=df.topic_id, palette=sns.color_palette("muted", 10))

# %%
plt.figure(figsize=(16,7))
sns.scatterplot(x=df.X, y=df.Y, hue=df.type, palette=sns.color_palette("muted", 8))
