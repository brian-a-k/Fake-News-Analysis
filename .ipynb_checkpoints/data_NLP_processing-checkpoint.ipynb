# %% [markdown]
# ## Data Clean-up and Pre-Processing
#
# - Brian K
# - Edited: 10/26/2019

# %%
import pandas as pd
import numpy as np
from collections import *
import string

# Custom Code imports
import sys
sys.path.insert(0, '/Users/briankalinowski/PycharmProjects/FakeNewsChallenge/Code')
import DataProcessing as pro

# %% [markdown]
# # All news

# %%
news_data = pd.read_csv('/Users/briankalinowski/Desktop/Data/General_News/all_the_news.csv')
news_data.drop(columns=['year', 'month'], inplace=True)
news_data.date = pd.to_datetime(news_data.date)
news_data.head()
# Out:
#       id                                              title     publication  \
# 0  17283  House Republicans Fret About Winning Their Hea...  New York Times
# 1  17284  Rift Between Officers and Residents as Killing...  New York Times
# 2  17285  Tyrus Wong, ‘Bambi’ Artist Thwarted by Racial ...  New York Times
# 3  17286  Among Deaths in 2016, a Heavy Toll in Pop Musi...  New York Times
# 4  17287  Kim Jong-un Says North Korea Is Preparing to T...  New York Times
#
#                           author       date  url  \
# 0                     Carl Hulse 2016-12-31  NaN
# 1  Benjamin Mueller and Al Baker 2017-06-19  NaN
# 2                   Margalit Fox 2017-01-06  NaN
# 3               William McDonald 2017-04-10  NaN
# 4                  Choe Sang-Hun 2017-01-02  NaN
#
#                                              content
# 0  WASHINGTON  —   Congressional Republicans have...
# 1  After the bullet shells get counted, the blood...
# 2  When Walt Disney’s “Bambi” opened in 1942, cri...
# 3  Death may be the great equalizer, but it isn’t...
# 4  SEOUL, South Korea  —   North Korea’s leader, ...

# %%
fill_vals = {'title': 'NO_TITLE', 
             'author': 'NO_AUTHOR', 
             'url': 'NO_URL'
            }

news_data = pro.fill_null_string_columns(news_data, fill_vals)

# %%
news_data.head()
# Out:
#       id                                              title     publication  \
# 0  17283  House Republicans Fret About Winning Their Hea...  New York Times
# 1  17284  Rift Between Officers and Residents as Killing...  New York Times
# 2  17285  Tyrus Wong, ‘Bambi’ Artist Thwarted by Racial ...  New York Times
# 3  17286  Among Deaths in 2016, a Heavy Toll in Pop Musi...  New York Times
# 4  17287  Kim Jong-un Says North Korea Is Preparing to T...  New York Times
#
#                           author       date     url  \
# 0                     Carl Hulse 2016-12-31  NO_URL
# 1  Benjamin Mueller and Al Baker 2017-06-19  NO_URL
# 2                   Margalit Fox 2017-01-06  NO_URL
# 3               William McDonald 2017-04-10  NO_URL
# 4                  Choe Sang-Hun 2017-01-02  NO_URL
#
#                                              content
# 0  WASHINGTON  —   Congressional Republicans have...
# 1  After the bullet shells get counted, the blood...
# 2  When Walt Disney’s “Bambi” opened in 1942, cri...
# 3  Death may be the great equalizer, but it isn’t...
# 4  SEOUL, South Korea  —   North Korea’s leader, ...

# %%
news_content = news_data[['title', 'content', 'publication']]
news_content['content_length'] = news_content.content.str.len()
news_content = news_content.sort_values(by=['content_length'], ascending=False)
news_content= news_content.reset_index(drop=True)
news_content.head()
# Out:
# /anaconda/envs/FakeNewsChallenge/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                                title  \
# 0  Full transcript: FBI Director James Comey test...
# 1   \nWill the Liberal Bubble Burst? Your Thoughts\n
# 2  Full transcript: Sally Yates and James Clapper...
# 3               \nTake It From a ‘Liberal Redneck’\n
# 4     \nTrying to Avoid Politics Over Thanksgiving\n
#
#                                              content      publication  \
# 0           Below is the full transcript from the...  Washington Post
# 1  Atlantic readers from across the political spe...         Atlantic
# 2            Former acting attorney general Sally...  Washington Post
# 3     Atlantic readers from across the political ...         Atlantic
# 4  Atlantic readers from across the political spe...         Atlantic
#
#    content_length
# 0          292586
# 1          164658
# 2          162120
# 3          162104
# 4          152708

# %%
news_content = pro.clean_text_column(news_content, 'title')
news_content = pro.clean_text_column(news_content, 'content')
news_content.head()
# Out:
#                                                title  \
# 0  Full transcript FBI Director James Comey testi...
# 1       Will the Liberal Bubble Burst? Your Thoughts
# 2  Full transcript Sally Yates and James Clapper ...
# 3                     Take It From a Liberal Redneck
# 4         Trying to Avoid Politics Over Thanksgiving
#
#                                              content      publication  \
# 0           Below is the full transcript from the...  Washington Post
# 1  Atlantic readers from across the political spe...         Atlantic
# 2            Former acting attorney general Sally...  Washington Post
# 3     Atlantic readers from across the political ...         Atlantic
# 4  Atlantic readers from across the political spe...         Atlantic
#
#    content_length
# 0          292586
# 1          164658
# 2          162120
# 3          162104
# 4          152708

# %% [markdown]
# ## Fake news

# %%
fake_news = pd.read_csv('/Users/briankalinowski/Desktop/Data/Kaggle/fake_news.csv')
fake_news.drop(columns=['uuid', 'ord_in_thread', 'published'], inplace=True)
fake_news = fake_news.dropna(subset=['text'])
fake_news.head()
# Out:
#                  author                                              title  \
# 0     Barracuda Brigade  Muslims BUSTED: They Stole Millions In Gov’t B...
# 1  reasoning with facts  Re: Why Did Attorney General Loretta Lynch Ple...
# 2     Barracuda Brigade  BREAKING: Weiner Cooperating With FBI On Hilla...
# 3                Fed Up  PIN DROP SPEECH BY FATHER OF DAUGHTER Kidnappe...
# 4                Fed Up  FANTASTIC! TRUMP'S 7 POINT PLAN To Reform Heal...
#
#                                                 text language  \
# 0  Print They should pay all the back all the mon...  english
# 1  Why Did Attorney General Loretta Lynch Plead T...  english
# 2  Red State : \nFox News Sunday reported this mo...  english
# 3  Email Kayla Mueller was a prisoner and torture...  english
# 4  Email HEALTHCARE REFORM TO MAKE AMERICA GREAT ...  english
#
#                          crawled             site_url country  domain_rank  \
# 0  2016-10-27T01:49:27.168+03:00  100percentfedup.com      US      25689.0
# 1  2016-10-29T08:47:11.259+03:00  100percentfedup.com      US      25689.0
# 2  2016-10-31T01:41:49.479+02:00  100percentfedup.com      US      25689.0
# 3  2016-11-01T15:46:26.304+02:00  100percentfedup.com      US      25689.0
# 4  2016-11-01T23:59:42.266+02:00  100percentfedup.com      US      25689.0
#
#                                         thread_title  spam_score  \
# 0  Muslims BUSTED: They Stole Millions In Gov’t B...       0.000
# 1  Re: Why Did Attorney General Loretta Lynch Ple...       0.000
# 2  BREAKING: Weiner Cooperating With FBI On Hilla...       0.000
# 3  PIN DROP SPEECH BY FATHER OF DAUGHTER Kidnappe...       0.068
# 4  FANTASTIC! TRUMP'S 7 POINT PLAN To Reform Heal...       0.865
#
#                                         main_img_url  replies_count  \
# 0  http://bb4sp.com/wp-content/uploads/2016/10/Fu...              0
# 1  http://bb4sp.com/wp-content/uploads/2016/10/Fu...              0
# 2  http://bb4sp.com/wp-content/uploads/2016/10/Fu...              0
# 3  http://100percentfedup.com/wp-content/uploads/...              0
# 4  http://100percentfedup.com/wp-content/uploads/...              0
#
#    participants_count  likes  comments  shares  type
# 0                   1      0         0       0  bias
# 1                   1      0         0       0  bias
# 2                   1      0         0       0  bias
# 3                   0      0         0       0  bias
# 4                   0      0         0       0  bias

# %%
fake_news_content = fake_news[['title', 'text', 'type']]
fake_news_content = fake_news_content.reset_index(drop=True)
# fake_news_content.title = fake_news_content.title.apply(lambda row: str(row).lower())
# fake_news_content.text = fake_news_content.text.apply(lambda row: str(row).lower())
fake_news_content = pro.clean_text_column(fake_news_content, 'title')
fake_news_content = pro.clean_text_column(fake_news_content, 'text')
fake_news_content.head()
# Out:
#                                                title  \
# 0  Muslims BUSTED They Stole Millions In Gov’t Be...
# 1  Re Why Did Attorney General Loretta Lynch Plea...
# 2  BREAKING Weiner Cooperating With FBI On Hillar...
# 3  PIN DROP SPEECH BY FATHER OF DAUGHTER Kidnappe...
# 4  FANTASTIC! TRUMPS 7 POINT PLAN To Reform Healt...
#
#                                                 text  type
# 0  Print They should pay all the back all the mon...  bias
# 1  Why Did Attorney General Loretta Lynch Plead T...  bias
# 2  Red State  Fox News Sunday reported this morni...  bias
# 3  Email Kayla Mueller was a prisoner and torture...  bias
# 4  Email HEALTHCARE REFORM TO MAKE AMERICA GREAT ...  bias

# %%
fake_news_content.type.value_counts()
# Out:
# bs            11492
# bias            443
# conspiracy      430
# hate            246
# state           121
# junksci         102
# satire          100
# fake             19
# Name: type, dtype: int64

# %%
import spacy
from collections import defaultdict
nlp = spacy.load('en_core_web_md')

pipline = nlp.pipe(bias_headlines, disable=["tagger", "parser"])
entity_dict = defaultdict(list)
for doc in pipline:
    for entity in doc.ents:
        entity_dict[str(entity.label_)].append(str(entity.text))

# %%
entity_dict
# Out:
# defaultdict(list,
#             {'NORP': ['Muslims',
#               'Americans',
#               'BRITISH',
#               'Democrat',
#               'Republicans',
#               'Arab',
#               'Muslim',
#               'Democrats',
#               'Democratic',
#               'Democrat',
#               'Conservatives',
#               'Democrats',
#               'Democrats',
#               'Republicans',
#               'Democrats',
#               'Republican',
#               'Republicans',
#               'Khans',
#               'Republicans',
#               'Democrats',
#               'Republicans',
#               'Republicans',
#               'Democrats',
#               'Republicans',
#               'Republicans',
#               'Democratic',
#               'Kenyan',
#               'Kenyan',
#               'Dems',
#               'Dems',
#               'Democrats',
#               'Irans',
#               'Democrats',
#               'Irans',
#               'Dems',
#               'Dems',
#               'Christs',
#               'Indian'],
#              'PERSON': ['Loretta Lynch',
#               'Donald J. Trump',
#               'Hillary Goes',
#               'NYPD Ready',
#               'CLINTON',
#               'HILLARY',
#               'HILLARY',
#               'ProTrump Chalkings',
#               'Reagan',
#               'MARK CUBAN',
#               'Donald TrumpWarns',
#               'DONALD TRUMP',
#               'HAMILTON',
#               'Cuomo',
#               'CLARKE',
#               'Jake Tapper',
#               'Sarah Palin',
#               'Trump Smacked',
#               'Melania Trump',
#               'Hillary Grab',
#               'Lindsey Graham',
#               'Ted Cruz',
#               'Michelle Obama',
#               'Megyn Kelly',
#               'Bernie Sanders Rises',
#               'Ben Shapiro',
#               'Michelle Obama',
#               'Obama',
#               'Hillary Clinton',
#               'George',
#               'Laura Bush',
#               'Nude Selfie',
#               'Hillarys Climactic',
#               'Donna Brazile',
#               'Michael Moore',
#               'Hillary IMPLODES',
#               'Hillary Aides',
#               'Hillary',
#               'Obama',
#               'Comey',
#               'Putin',
#               'Obama',
#               'Hillary',
#               'Christie Lost',
#               'Clinton',
#               'Matthew Yglesias',
#               'Clinton Campaign Harwoods',
#               'Hillary',
#               'Hillary Won More Votes',
#               'Donald Trump',
#               'Limbaugh',
#               'Bernie Sanders Wont',
#               'Yoko Onos',
#               'Trump Begins',
#               'Steve Bannon',
#               'Jeff Sessions',
#               'Obama',
#               'Kerry',
#               'Kanye Tour Cancelled',
#               'Kanye Hospitalized',
#               'Obama',
#               'Obama',
#               'Mike Rowe Schools',
#               'Tim Allen',
#               'Donald Trump Jr.',
#               'Clinton',
#               'Clinton',
#               'Khan',
#               'Clinton',
#               'Paul Ryan',
#               'Donald Trump Tanking',
#               'Hillary Clinton',
#               'Hillary Clinton',
#               'Michelle Obama',
#               'Marco Rubio',
#               'Bernie Sanders',
#               'Donald Trump',
#               'Mike Pence',
#               'Mark Kirk',
#               'Tammy Duckworth',
#               'Donald Trump’s',
#               'Hillary Clinton',
#               'Marco Rubio Inches',
#               'Mike Pence',
#               'Clinton',
#               'Donald Trump In The Face',
#               'Hillary Clinton’s',
#               'Donald Trump',
#               'Hillary Clinton',
#               'James Comey',
#               'James Comey',
#               'Hillary Clinton',
#               'Comey',
#               'Hillary Clinton',
#               'Donald Trump',
#               'Clinton',
#               'Obama Gets',
#               'Trump Attacked',
#               'Clinton',
#               'Clinton',
#               'Hillary Clinton',
#               'David Fahrenthold Strikes',
#               'Donald Trump’s',
#               'Clinton',
#               'Hillary Clinton',
#               'Comey Email',
#               'Comey',
#               'George W. Bush’s',
#               'James Comey',
#               'Hillary Clinton',
#               'James Comey',
#               'Obama',
#               'Comey',
#               'Donald Trump',
#               'Donald Trump',
#               'Jason Chaffetz',
#               'Comey Clinton',
#               'Joking About',
#               'Clinton',
#               'Comey Bias Exposed',
#               'Trump Crushed',
#               'Hillary Clinton’s',
#               'Donald Trump',
#               'Rachel Maddow',
#               'Comey Must',
#               'Comey Letter Hurts',
#               'Hillary Clinton',
#               'Hillary Clinton',
#               'Donald Trump',
#               'David Bossie',
#               'Paul Ryan',
#               'Sean Hannity',
#               'Donald Trump',
#               'Hillary Clinton',
#               'Hillary Clinton',
#               'Hillary',
#               'Bill Clinton',
#               'Millions Face',
#               'Newt Gingrich',
#               'Donald Trump',
#               'ProClinton Super',
#               'Elizabeth Smart Realizes Kidnapping Was Even Worse For Her Parents',
#               'Obamas',
#               'Clinton',
#               'Hillary',
#               'Trump',
#               'Limbaugh Democrats',
#               'Jesus Christ',
#               'Limbaugh Democrats',
#               'Jesus Christ',
#               'Bill Clinton',
#               'Bill Clinton',
#               'Sheriff Joe',
#               'Sheriff Joe',
#               'Jesus',
#               'Loretta Lynch',
#               'Hillarys',
#               'Trumpers',
#               'Clinton',
#               'Megyn Kelly',
#               'Clinton',
#               'Clintons',
#               'Loretta Lynch',
#               'Hillarys',
#               'Trumpers',
#               'Clinton',
#               'Megyn Kelly',
#               'Clintons',
#               'Hillary',
#               'Hillarys',
#               'Hillarys',
#               'Hillary',
#               'Fatherson',
#               'Fatherson',
#               'Putin',
#               'Trump',
#               'Rand Paul',
#               'Putin',
#               'Trump',
#               'Rand Paul',
#               'Hillary',
#               'Obamas',
#               'Munichmassacre'],
#              'ORDINAL': ['Fifth', '70th', '1st'],
#              'ORG': ['BREAKING Weiner Cooperating',
#               'FBI',
#               'Hillary Email Investigation',
#               'TimesMoney',
#               'PayforPlay',
#               'WHISTLEBLOWER',
#               'MSNBC',
#               'NYC',
#               'SNL',
#               'CNN',
#               'NWord',
#               'Kellyanne Conway',
#               'Kellyanne Conway LOSES IT On',
#               'The Toronto Star Published An Unauthorized Database’ Of Things That Will INFURIATE',
#               'The Supreme Court',
#               'People Arrested For Food Stamp Fraud',
#               'The Simpsons’ React To Their Trump Election Prediction',
#               'Senate',
#               'Run For Office',
#               'The Dakota Access Pipeline Protests',
#               'Supreme Court',
#               'New York Times Tries',
#               'Hoover',
#               'NYT',
#               'Report New York Times Profit',
#               'FBI',
#               'State',
#               'NYT',
#               'Clemson University Students Welcome Ben Shapiro',
#               'Hillary’s',
#               'Said  Daily Wire',
#               'DNC',
#               'Robbed by Gang of Hillary Supporters  Daily Wire',
#               'NC State Provides Students with PostElection Comfort Food',
#               'Chelsea',
#               'White House',
#               'Shapiro',
#               'Gallup Americans More Confident',
#               'CIA',
#               'Tapper Pushes Conflict Of Interest Narrative',
#               'CNN',
#               'GOP',
#               '’s Good News',
#               'Trump Rips Press in Private Meeting',
#               'GOP',
#               'DC Hotel',
#               'The Dream Team',
#               'MixedRace Heritage',
#               'Florida Senate',
#               'GOP',
#               'DOJ Complaint',
#               'FBI',
#               'FBI',
#               'DOJ Spokesman',
#               'Megyn',
#               'Fox News',
#               'GOP',
#               'Koch Brothers',
#               'Concert',
#               'FBI',
#               'ReutersIpsos',
#               'The Religious Right Warns Witchcraft',
#               'FBI',
#               'FBI',
#               'Fox News Gets Destroyed While Trying To Blame',
#               'GOP',
#               'FBI',
#               'Supreme Court Decides to Weigh',
#               'The Catholic Church',
#               'Ditch Media Propaganda Scam',
#               'GOP',
#               'FBI',
#               'Trump’s White Supremacist Support',
#               'GOP',
#               'The Lowest Score In History Of Presidential Leadership Poll',
#               'FBI',
#               'GOP',
#               'House',
#               'Veritas',
#               'WH Press',
#               'Trump',
#               'Trump',
#               'Dow',
#               'Boeing',
#               'Dow',
#               'Boeing',
#               'Impeachmentera',
#               'U.N.',
#               'U.N.',
#               'Impeachmentera',
#               'Trump',
#               'Gingrich',
#               'Trump',
#               'Gingrich',
#               'WikiLeaks',
#               'WikiLeaks',
#               'Hillary',
#               'Hillary',
#               'NATO',
#               'Exrep',
#               'U.S. Treasury',
#               'NATO',
#               'Exrep',
#               'U.S. Treasury',
#               'Trump',
#               'Obamacare',
#               'GOP',
#               'Trumps',
#               'Trump',
#               'Obamacare',
#               'GOP',
#               'Trumps',
#               'Hillarythemed',
#               'Skype'],
#              'CARDINAL': ['7',
#               '23',
#               '12',
#               '30',
#               '8',
#               '4',
#               '4',
#               'FIVE',
#               '7',
#               '11',
#               '4',
#               '7',
#               '3',
#               '5',
#               '7',
#               '750,000',
#               '11',
#               '7',
#               'Three',
#               '12',
#               '4',
#               '4',
#               '37',
#               '75',
#               '11.3 Million',
#               '370',
#               '14',
#               '275,000',
#               '275,000',
#               '29',
#               '7',
#               '29',
#               '7',
#               '26',
#               '33,000',
#               '33,000',
#               '26',
#               '19',
#               '19',
#               '620,000',
#               '620,000',
#               '58',
#               'millions',
#               '58',
#               'millions'],
#              'WORK_OF_ART': ['Underage Sex',
#               'This A Coordinated Last Minute Trick To Energize Hillarys Base',
#               'NOWAnd This One’s Going In The White House',
#               'A Silver Lining For America',
#               'The Best Picture In Human History  Daily Wire',
#               'Interfering In Presidential Election',
#               'Lock Her Up!',
#               'Quran',
#               'Quran',
#               'Hebrew',
#               'Hebrew'],
#              'GPE': ['Hollywood',
#               'BoycottComedianROBERT',
#               'AMERICA',
#               'Texas',
#               'California',
#               'U.S.',
#               'Texas',
#               'Syria',
#               'Finland',
#               'North Carolina',
#               'Ohio',
#               'Arizona',
#               'Arizona',
#               'Russia',
#               'North Carolina',
#               'Russia',
#               'Russia',
#               'Florida',
#               'Texas',
#               'Florida',
#               'D.C.',
#               'D.C.',
#               'Jerusalem',
#               'Jerusalem',
#               'Israel',
#               'Russia',
#               'Samaritan'],
#              'EVENT': ['TUCKER CARLSON Demolishes',
#               'The 2012 Election',
#               'This Awful Election Day',
#               'World War 3'],
#              'PERCENT': ['2.7 Percent'],
#              'DATE': ['Two Weeks',
#               '2016',
#               '2020',
#               'the First 19 Days of October',
#               'Friday',
#               'this Week',
#               'October',
#               'October',
#               'November 9',
#               '6 Months',
#               'Years',
#               'Nearly 50 Years',
#               '13 Years Later',
#               '1 year',
#               '1 year',
#               'The early years',
#               'The early years',
#               '40 years',
#               '40 years',
#               'Satan 2'],
#              'LAW': ['Trump Throws A Fit When Asked Why He Is Promoting His Hotel Instead Of Campaigning',
#               'Trump’s Campaign Backfires',
#               'Trump Proposes Canceling Election'],
#              'FAC': ['LaGuardia Airport'],
#              'TIME': ['72 Hours'],
#              'LOC': ['Siberia', 'Siberia']})
